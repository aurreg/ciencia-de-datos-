# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
from sklearn import metrics
from sklearn.metrics import roc_curve, auc

# Cargar el dataset
SUPPPORT2 =  pd.read_csv("SUPPORT2_FAMD.csv")
SUPPPORT2
# Out:
#          Dim.1     Dim.2     Dim.3     Dim.4     Dim.5  death
# 0    -0.194339 -3.230119 -2.116084  1.962819  4.215209      0
# 1     5.838293  0.464790  0.433471  0.845171 -2.540348      1
# 2    -1.391069  0.276359  0.864646 -0.131425 -1.403475      1
# 3    -2.959605 -1.906638 -2.899396  0.359846 -0.740216      1
# 4    -0.766582  1.574329 -0.092996 -0.719865 -0.096621      0
# ...        ...       ...       ...       ...       ...    ...
# 9100 -1.773661  1.845368 -0.492387 -0.625138  0.692517      0
# 9101  0.527968 -0.485235  0.395812 -5.096458 -0.167435      0
# 9102 -0.762929  1.772981 -0.138894  0.129657  0.876572      0
# 9103  4.739101 -1.252125 -1.069302  1.350317 -2.245746      1
# 9104 -2.397621  0.278965  0.387839 -0.236839 -0.406526      1
#
# [9105 rows x 6 columns]
